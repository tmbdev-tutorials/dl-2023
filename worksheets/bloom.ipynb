# %%
# %pylab inline
# Out:
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib

# %%
mname = "bigscience/bloom-560m"
# mname = "bigscience/bloom-1.3b"
# mname = "bigscience/bloom"
from transformers import BloomTokenizerFast, BloomForTokenClassification, BloomForCausalLM
from transformers import pipeline, TextGenerationPipeline
class bloom_model:
    def __init__(self):
        self.tokenizer = BloomTokenizerFast.from_pretrained(mname)
        self.model = BloomForCausalLM.from_pretrained(mname)
        
        self.generator = TextGenerationPipeline(
            task = 'text-generation',
            model = self.model,
            tokenizer = self.tokenizer
        )

    def predict(self, content: str) -> str:
            answer = self.generator(content, max_new_tokens=100)
            return answer

model = bloom_model()
# Out:
# /Users/tbreuel/opt/anaconda3/envs/pytorch/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
model.predict("Examples of Viking gods are")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/tbreuel/tutorials/dl-2022/worksheets/bloom.ipynb Cell 3 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/tbreuel/tutorials/dl-2022/worksheets/bloom.ipynb#W2sZmlsZQ%3D%3D?line=0'>1</a> model.predict("Examples of Viking gods are")
#
# /Users/tbreuel/tutorials/dl-2022/worksheets/bloom.ipynb Cell 3 in bloom_model.predict(self, content)
#      <a href='vscode-notebook-cell:/Users/tbreuel/tutorials/dl-2022/worksheets/bloom.ipynb#W2sZmlsZQ%3D%3D?line=16'>17</a> def predict(self, content: str) -> str:
# ---> <a href='vscode-notebook-cell:/Users/tbreuel/tutorials/dl-2022/worksheets/bloom.ipynb#W2sZmlsZQ%3D%3D?line=17'>18</a>         answer = self.generator(content, max_new_tokens=100)
#      <a href='vscode-notebook-cell:/Users/tbreuel/tutorials/dl-2022/worksheets/bloom.ipynb#W2sZmlsZQ%3D%3D?line=18'>19</a>         return answer
#
# File ~/opt/anaconda3/envs/pytorch/lib/python3.10/site-packages/transformers/pipelines/text_generation.py:187, in TextGenerationPipeline.__call__(self, text_inputs, **kwargs)
#     148 def __call__(self, text_inputs, **kwargs):
#     149     """
#     150     Complete the prompt(s) given as inputs.
#     151
#    (...)
#     185           ids of the generated text.
#     186     """
# --> 187     return super().__call__(text_inputs, **kwargs)
#
# File ~/opt/anaconda3/envs/pytorch/lib/python3.10/site-packages/transformers/pipelines/base.py:1074, in Pipeline.__call__(self, inputs, num_workers, batch_size, *args, **kwargs)
#    1072     return self.iterate(inputs, preprocess_params, forward_params, postprocess_params)
#    1073 else:
# -> 1074     return self.run_single(inputs, preprocess_params, forward_params, postprocess_params)
#
# File ~/opt/anaconda3/envs/pytorch/lib/python3.10/site-packages/transformers/pipelines/base.py:1081, in Pipeline.run_single(self, inputs, preprocess_params, forward_params, postprocess_params)
#    1079 def run_single(self, inputs, preprocess_params, forward_params, postprocess_params):
#    1080     model_inputs = self.preprocess(inputs, **preprocess_params)
# -> 1081     model_outputs = self.forward(model_inputs, **forward_params)
#    1082     outputs = self.postprocess(model_outputs, **postprocess_params)
#    1083     return outputs
#
# File ~/opt/anaconda3/envs/pytorch/lib/python3.10/site-packages/transformers/pipelines/base.py:990, in Pipeline.forward(self, model_inputs, **forward_params)
#     988     with inference_context():
#     989         model_inputs = self._ensure_tensor_on_device(model_inputs, device=self.device)
# --> 990         model_outputs = self._forward(model_inputs, **forward_params)
#     991         model_outputs = self._ensure_tensor_on_device(model_outputs, device=torch.device("cpu"))
#     992 else:
#
# File ~/opt/anaconda3/envs/pytorch/lib/python3.10/site-packages/transformers/pipelines/text_generation.py:229, in TextGenerationPipeline._forward(self, model_inputs, **generate_kwargs)
#     227 prompt_text = model_inputs.pop("prompt_text")
#     228 # BS x SL
# --> 229 generated_sequence = self.model.generate(input_ids=input_ids, attention_mask=attention_mask, **generate_kwargs)
#     230 out_b = generated_sequence.shape[0]
#     231 if self.framework == "pt":
#
# File ~/opt/anaconda3/envs/pytorch/lib/python3.10/site-packages/torch/autograd/grad_mode.py:27, in _DecoratorContextManager.__call__.<locals>.decorate_context(*args, **kwargs)
#      24 @functools.wraps(func)
#      25 def decorate_context(*args, **kwargs):
#      26     with self.clone():
# ---> 27         return func(*args, **kwargs)
#
# File ~/opt/anaconda3/envs/pytorch/lib/python3.10/site-packages/transformers/generation_utils.py:1390, in GenerationMixin.generate(self, inputs, max_length, min_length, do_sample, early_stopping, num_beams, temperature, top_k, top_p, typical_p, repetition_penalty, bad_words_ids, force_words_ids, bos_token_id, pad_token_id, eos_token_id, length_penalty, no_repeat_ngram_size, encoder_no_repeat_ngram_size, num_return_sequences, max_time, max_new_tokens, decoder_start_token_id, use_cache, num_beam_groups, diversity_penalty, prefix_allowed_tokens_fn, logits_processor, renormalize_logits, stopping_criteria, constraints, output_attentions, output_hidden_states, output_scores, return_dict_in_generate, forced_bos_token_id, forced_eos_token_id, remove_invalid_values, synced_gpus, exponential_decay_length_penalty, suppress_tokens, begin_suppress_tokens, forced_decoder_ids, **model_kwargs)
#    1385         raise ValueError(
#    1386             f"num_return_sequences has to be 1, but is {num_return_sequences} when doing greedy search."
#    1387         )
#    1389     # 10. run greedy search
# -> 1390     return self.greedy_search(
#    1391         input_ids,
#    1392         logits_processor=logits_processor,
#    1393         stopping_criteria=stopping_criteria,
#    1394         pad_token_id=pad_token_id,
#    1395         eos_token_id=eos_token_id,
#    1396         output_scores=output_scores,
#    1397         return_dict_in_generate=return_dict_in_generate,
#    1398         synced_gpus=synced_gpus,
#    1399         **model_kwargs,
#    1400     )
#    1402 elif is_sample_gen_mode:
#    1403     # 10. prepare logits warper
#    1404     logits_warper = self._get_logits_warper(
#    1405         top_k=top_k,
#    1406         top_p=top_p,
#    (...)
#    1410         renormalize_logits=renormalize_logits,
#    1411     )
#
# File ~/opt/anaconda3/envs/pytorch/lib/python3.10/site-packages/transformers/generation_utils.py:1785, in GenerationMixin.greedy_search(self, input_ids, logits_processor, stopping_criteria, max_length, pad_token_id, eos_token_id, output_attentions, output_hidden_states, output_scores, return_dict_in_generate, synced_gpus, **model_kwargs)
#    1782 model_inputs = self.prepare_inputs_for_generation(input_ids, **model_kwargs)
#    1784 # forward pass to get next token
# -> 1785 outputs = self(
#    1786     **model_inputs,
#    1787     return_dict=True,
#    1788     output_attentions=output_attentions,
#    1789     output_hidden_states=output_hidden_states,
#    1790 )
#    1792 if synced_gpus and this_peer_finished:
#    1793     continue  # don't waste resources running the code we don't need
#
# File ~/opt/anaconda3/envs/pytorch/lib/python3.10/site-packages/torch/nn/modules/module.py:1190, in Module._call_impl(self, *input, **kwargs)
#    1186 # If we don't have any hooks, we want to skip the rest of the logic in
#    1187 # this function, and just call forward.
#    1188 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1189         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1190     return forward_call(*input, **kwargs)
#    1191 # Do not call functions when jit is used
#    1192 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/opt/anaconda3/envs/pytorch/lib/python3.10/site-packages/transformers/models/bloom/modeling_bloom.py:860, in BloomForCausalLM.forward(self, input_ids, past_key_values, attention_mask, head_mask, inputs_embeds, labels, use_cache, output_attentions, output_hidden_states, return_dict, **deprecated_arguments)
#     856     raise ValueError(f"Got unexpected arguments: {deprecated_arguments}")
#     858 return_dict = return_dict if return_dict is not None else self.config.use_return_dict
# --> 860 transformer_outputs = self.transformer(
#     861     input_ids,
#     862     past_key_values=past_key_values,
#     863     attention_mask=attention_mask,
#     864     head_mask=head_mask,
#     865     inputs_embeds=inputs_embeds,
#     866     use_cache=use_cache,
#     867     output_attentions=output_attentions,
#     868     output_hidden_states=output_hidden_states,
#     869     return_dict=return_dict,
#     870 )
#     871 hidden_states = transformer_outputs[0]
#     873 lm_logits = self.lm_head(hidden_states)
#
# File ~/opt/anaconda3/envs/pytorch/lib/python3.10/site-packages/torch/nn/modules/module.py:1190, in Module._call_impl(self, *input, **kwargs)
#    1186 # If we don't have any hooks, we want to skip the rest of the logic in
#    1187 # this function, and just call forward.
#    1188 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1189         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1190     return forward_call(*input, **kwargs)
#    1191 # Do not call functions when jit is used
#    1192 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/opt/anaconda3/envs/pytorch/lib/python3.10/site-packages/transformers/models/bloom/modeling_bloom.py:745, in BloomModel.forward(self, input_ids, past_key_values, attention_mask, head_mask, inputs_embeds, use_cache, output_attentions, output_hidden_states, return_dict, **deprecated_arguments)
#     737     outputs = torch.utils.checkpoint.checkpoint(
#     738         create_custom_forward(block),
#     739         hidden_states,
#    (...)
#     742         head_mask[i],
#     743     )
#     744 else:
# --> 745     outputs = block(
#     746         hidden_states,
#     747         layer_past=layer_past,
#     748         attention_mask=causal_mask,
#     749         head_mask=head_mask[i],
#     750         use_cache=use_cache,
#     751         output_attentions=output_attentions,
#     752         alibi=alibi,
#     753     )
#     755 hidden_states = outputs[0]
#     756 if use_cache is True:
#
# File ~/opt/anaconda3/envs/pytorch/lib/python3.10/site-packages/torch/nn/modules/module.py:1190, in Module._call_impl(self, *input, **kwargs)
#    1186 # If we don't have any hooks, we want to skip the rest of the logic in
#    1187 # this function, and just call forward.
#    1188 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1189         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1190     return forward_call(*input, **kwargs)
#    1191 # Do not call functions when jit is used
#    1192 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/opt/anaconda3/envs/pytorch/lib/python3.10/site-packages/transformers/models/bloom/modeling_bloom.py:464, in BloomBlock.forward(self, hidden_states, alibi, attention_mask, layer_past, head_mask, use_cache, output_attentions)
#     461     residual = attention_output
#     463 # MLP.
# --> 464 output = self.mlp(layernorm_output, residual)
#     466 if use_cache:
#     467     outputs = (output,) + outputs
#
# File ~/opt/anaconda3/envs/pytorch/lib/python3.10/site-packages/torch/nn/modules/module.py:1190, in Module._call_impl(self, *input, **kwargs)
#    1186 # If we don't have any hooks, we want to skip the rest of the logic in
#    1187 # this function, and just call forward.
#    1188 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1189         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1190     return forward_call(*input, **kwargs)
#    1191 # Do not call functions when jit is used
#    1192 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/opt/anaconda3/envs/pytorch/lib/python3.10/site-packages/transformers/models/bloom/modeling_bloom.py:385, in BloomMLP.forward(self, hidden_states, residual)
#     384 def forward(self, hidden_states: torch.Tensor, residual: torch.Tensor) -> torch.Tensor:
# --> 385     hidden_states = self.gelu_impl(self.dense_h_to_4h(hidden_states))
#     387     if self.pretraining_tp > 1 and self.slow_but_exact:
#     388         intermediate_output = torch.zeros_like(residual)
#
# File ~/opt/anaconda3/envs/pytorch/lib/python3.10/site-packages/torch/nn/modules/module.py:1190, in Module._call_impl(self, *input, **kwargs)
#    1186 # If we don't have any hooks, we want to skip the rest of the logic in
#    1187 # this function, and just call forward.
#    1188 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1189         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1190     return forward_call(*input, **kwargs)
#    1191 # Do not call functions when jit is used
#    1192 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/opt/anaconda3/envs/pytorch/lib/python3.10/site-packages/transformers/models/bloom/modeling_bloom.py:209, in BloomGelu.forward(self, x)
#     207     return GeLUFunction.apply(x)
#     208 else:
# --> 209     return bloom_gelu_forward(x)
#
# File ~/opt/anaconda3/envs/pytorch/lib/python3.10/site-packages/transformers/models/bloom/modeling_bloom.py:159, in bloom_gelu_forward(x)
#     150 def bloom_gelu_forward(x: torch.Tensor) -> torch.Tensor:
#     151     """
#     152     Custom bias GELU function. Adapted from Megatron-DeepSpeed code. Here we use a simple implementation (inference) to
#     153     make the model jitable.
#    (...)
#     157             input hidden states
#     158     """
# --> 159     return x * 0.5 * (1.0 + torch.tanh(0.79788456 * x * (1 + 0.044715 * x * x)))
#
# KeyboardInterrupt:

# %%
model.predict("Examples of small, furry rodents living near humans are")
